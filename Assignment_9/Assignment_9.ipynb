# %% [markdown]
# # 1) Import the required libraries (sklearn, pandas, numpy). Import datasets. Concatenate the datasets. Display first 5 rows.#

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df1 = pd.read_csv('train.csv')
df2 = pd.read_csv('test.csv')
df1.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df2.head()
# Out:
#    PassengerId  Pclass                                          Name     Sex  \
# 0          892       3                              Kelly, Mr. James    male
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)  female
# 2          894       2                     Myles, Mr. Thomas Francis    male
# 3          895       3                              Wirz, Mr. Albert    male
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
#
#     Age  SibSp  Parch   Ticket     Fare Cabin Embarked
# 0  34.5      0      0   330911   7.8292   NaN        Q
# 1  47.0      1      0   363272   7.0000   NaN        S
# 2  62.0      0      0   240276   9.6875   NaN        Q
# 3  27.0      0      0   315154   8.6625   NaN        S
# 4  22.0      1      1  3101298  12.2875   NaN        S

# %%
df = pd.concat([df1,df2],axis=0,sort=True)
df.head()
# Out:
#     Age Cabin Embarked     Fare  \
# 0  22.0   NaN        S   7.2500
# 1  38.0   C85        C  71.2833
# 2  26.0   NaN        S   7.9250
# 3  35.0  C123        S  53.1000
# 4  35.0   NaN        S   8.0500
#
#                                                 Name  Parch  PassengerId  \
# 0                            Braund, Mr. Owen Harris      0            1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...      0            2
# 2                             Heikkinen, Miss. Laina      0            3
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)      0            4
# 4                           Allen, Mr. William Henry      0            5
#
#    Pclass     Sex  SibSp  Survived            Ticket
# 0       3    male      1       0.0         A/5 21171
# 1       1  female      1       1.0          PC 17599
# 2       3  female      0       1.0  STON/O2. 3101282
# 3       1  female      1       1.0            113803
# 4       3    male      0       0.0            373450

# %%
df1.shape
# Out:
# (891, 12)

# %%
df2.shape
# Out:
# (418, 11)

# %%
df.shape
# Out:
# (1309, 12)

# %% [markdown]
# # 2) Remove NaN values from the column ‘Survived’. #

# %%
df = df.dropna(subset=['Survived'])
df
# Out:
#       Age        Cabin Embarked      Fare  \
# 0    22.0          NaN        S    7.2500
# 1    38.0          C85        C   71.2833
# 2    26.0          NaN        S    7.9250
# 3    35.0         C123        S   53.1000
# 4    35.0          NaN        S    8.0500
# 5     NaN          NaN        Q    8.4583
# 6    54.0          E46        S   51.8625
# 7     2.0          NaN        S   21.0750
# 8    27.0          NaN        S   11.1333
# 9    14.0          NaN        C   30.0708
# 10    4.0           G6        S   16.7000
# 11   58.0         C103        S   26.5500
# 12   20.0          NaN        S    8.0500
# 13   39.0          NaN        S   31.2750
# 14   14.0          NaN        S    7.8542
# 15   55.0          NaN        S   16.0000
# 16    2.0          NaN        Q   29.1250
# 17    NaN          NaN        S   13.0000
# 18   31.0          NaN        S   18.0000
# 19    NaN          NaN        C    7.2250
# 20   35.0          NaN        S   26.0000
# ...

# %% [markdown]
# # 3.Create a new column 'Has_Cabin' that tells you whether passengers had a cabin or not.

# %%
df['Has_cabin'] = df.apply(lambda row: 'yes' if pd.notnull(row.Cabin) else 'No', axis=1)

# %%
df.head()
# Out:
#     Age Cabin Embarked     Fare  \
# 0  22.0   NaN        S   7.2500
# 1  38.0   C85        C  71.2833
# 2  26.0   NaN        S   7.9250
# 3  35.0  C123        S  53.1000
# 4  35.0   NaN        S   8.0500
#
#                                                 Name  Parch  PassengerId  \
# 0                            Braund, Mr. Owen Harris      0            1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...      0            2
# 2                             Heikkinen, Miss. Laina      0            3
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)      0            4
# 4                           Allen, Mr. William Henry      0            5
#
#    Pclass     Sex  SibSp  Survived            Ticket Has_cabin
# 0       3    male      1       0.0         A/5 21171        No
# 1       1  female      1       1.0          PC 17599       yes
# 2       3  female      0       1.0  STON/O2. 3101282        No
# 3       1  female      1       1.0            113803       yes
# ...

# %% [markdown]
# # 4) Create a new column “Title”, which will contain the titles of the passengers such as Mr., Mrs., etc. There should be five titles: Mr, Mrs, Master, Miss, and Special. #

# %%
import re
df['Title'] = df.apply(lambda r:''.join(re.findall(', M[\w]+',r.Name)),axis=1)

# %%
df.head()
# Out:
#     Age Cabin Embarked     Fare  \
# 0  22.0   NaN        S   7.2500
# 1  38.0   C85        C  71.2833
# 2  26.0   NaN        S   7.9250
# 3  35.0  C123        S  53.1000
# 4  35.0   NaN        S   8.0500
#
#                                                 Name  Parch  PassengerId  \
# 0                            Braund, Mr. Owen Harris      0            1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...      0            2
# 2                             Heikkinen, Miss. Laina      0            3
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)      0            4
# 4                           Allen, Mr. William Henry      0            5
#
#    Pclass     Sex  SibSp  Survived            Ticket Has_cabin   Title
# 0       3    male      1       0.0         A/5 21171        No    , Mr
# 1       1  female      1       1.0          PC 17599       yes   , Mrs
# 2       3  female      0       1.0  STON/O2. 3101282        No  , Miss
# ...

# %%
df
# Out:
#       Age        Cabin Embarked      Fare  \
# 0    22.0          NaN        S    7.2500
# 1    38.0          C85        C   71.2833
# 2    26.0          NaN        S    7.9250
# 3    35.0         C123        S   53.1000
# 4    35.0          NaN        S    8.0500
# 5     NaN          NaN        Q    8.4583
# 6    54.0          E46        S   51.8625
# 7     2.0          NaN        S   21.0750
# 8    27.0          NaN        S   11.1333
# 9    14.0          NaN        C   30.0708
# 10    4.0           G6        S   16.7000
# 11   58.0         C103        S   26.5500
# 12   20.0          NaN        S    8.0500
# 13   39.0          NaN        S   31.2750
# 14   14.0          NaN        S    7.8542
# 15   55.0          NaN        S   16.0000
# 16    2.0          NaN        Q   29.1250
# 17    NaN          NaN        S   13.0000
# 18   31.0          NaN        S   18.0000
# 19    NaN          NaN        C    7.2250
# 20   35.0          NaN        S   26.0000
# ...

# %% [markdown]
# # 5. Impute the missing values using .fillna() method. #

# %%
df = df.fillna(df.mean()).round(2)

# %%
df.head()
# Out:
#     Age Cabin Embarked   Fare  \
# 0  22.0   NaN        S   7.25
# 1  38.0   C85        C  71.28
# 2  26.0   NaN        S   7.92
# 3  35.0  C123        S  53.10
# 4  35.0   NaN        S   8.05
#
#                                                 Name  Parch  PassengerId  \
# 0                            Braund, Mr. Owen Harris      0            1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...      0            2
# 2                             Heikkinen, Miss. Laina      0            3
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)      0            4
# 4                           Allen, Mr. William Henry      0            5
#
#    Pclass     Sex  SibSp  Survived            Ticket Has_cabin   Title
# 0       3    male      1       0.0         A/5 21171        No    , Mr
# 1       1  female      1       1.0          PC 17599       yes   , Mrs
# 2       3  female      0       1.0  STON/O2. 3101282        No  , Miss
# ...

# %%
df
# Out:
#       Age        Cabin Embarked    Fare  \
# 0    22.0          NaN        S    7.25
# 1    38.0          C85        C   71.28
# 2    26.0          NaN        S    7.92
# 3    35.0         C123        S   53.10
# 4    35.0          NaN        S    8.05
# 5    29.7          NaN        Q    8.46
# 6    54.0          E46        S   51.86
# 7     2.0          NaN        S   21.08
# 8    27.0          NaN        S   11.13
# 9    14.0          NaN        C   30.07
# 10    4.0           G6        S   16.70
# 11   58.0         C103        S   26.55
# 12   20.0          NaN        S    8.05
# 13   39.0          NaN        S   31.28
# 14   14.0          NaN        S    7.85
# 15   55.0          NaN        S   16.00
# 16    2.0          NaN        Q   29.12
# 17   29.7          NaN        S   13.00
# 18   31.0          NaN        S   18.00
# 19   29.7          NaN        C    7.22
# 20   35.0          NaN        S   26.00
# 21   34.0          D56        S   13.00
# ...

# %% [markdown]
# # 7) Drop columns Cabin, Name, Passengerid, Ticket, Age, Fare, SibSp, Parch.#

# %%
df3 = df.drop(columns = ['Cabin', 'Name', 'Ticket', 'Age', 'Fare', 'SibSp', 'Parch'],axis=1)
df3
# Out:
#     Embarked  PassengerId  Pclass     Sex  Survived Has_cabin     Title
# 0          S            1       3    male       0.0        No      , Mr
# 1          C            2       1  female       1.0       yes     , Mrs
# 2          S            3       3  female       1.0        No    , Miss
# 3          S            4       1  female       1.0       yes     , Mrs
# 4          S            5       3    male       0.0        No      , Mr
# 5          Q            6       3    male       0.0        No      , Mr
# 6          S            7       1    male       0.0       yes      , Mr
# 7          S            8       3    male       0.0        No  , Master
# 8          S            9       3  female       1.0        No     , Mrs
# 9          C           10       2  female       1.0        No     , Mrs
# 10         S           11       3  female       1.0       yes    , Miss
# 11         S           12       1  female       1.0       yes    , Miss
# ...

# %% [markdown]
# # 8) Transform all variables into numeric ones using get_dummies().#

# %%
df = pd.get_dummies(df, columns=['Survived'])

# %%
df
# Out:
#       Age        Cabin Embarked    Fare  \
# 0    22.0          NaN        S    7.25
# 1    38.0          C85        C   71.28
# 2    26.0          NaN        S    7.92
# 3    35.0         C123        S   53.10
# 4    35.0          NaN        S    8.05
# 5    29.7          NaN        Q    8.46
# 6    54.0          E46        S   51.86
# 7     2.0          NaN        S   21.08
# 8    27.0          NaN        S   11.13
# 9    14.0          NaN        C   30.07
# 10    4.0           G6        S   16.70
# 11   58.0         C103        S   26.55
# 12   20.0          NaN        S    8.05
# 13   39.0          NaN        S   31.28
# 14   14.0          NaN        S    7.85
# 15   55.0          NaN        S   16.00
# 16    2.0          NaN        Q   29.12
# 17   29.7          NaN        S   13.00
# 18   31.0          NaN        S   18.00
# 19   29.7          NaN        C    7.22
# 20   35.0          NaN        S   26.00
# 21   34.0          D56        S   13.00
# ...

# %%
df.columns
# Out:
# Index(['Age', 'Cabin', 'Embarked', 'Fare', 'Name', 'Parch', 'PassengerId',
#        'Pclass', 'Sex', 'SibSp', 'Ticket', 'Has_cabin', 'Title',
#        'Survived_0.0', 'Survived_1.0'],
#       dtype='object')

# %% [markdown]
# # 9. Now we need training set and testing set. Use train_test_split() to split your dataset. X(Features) will be the dataset values without the column “Survived” and y(Targets) will be your “Survived” column values.#

# %%
x= np.array(df[['Age', 'Fare', 'Parch', 'PassengerId', 'Pclass',
     'SibSp']])
y= np.array(df['Survived_0.0'])

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,Y_train,Y_test = train_test_split(x,y,test_size=0.25,random_state=0)
print(X_train.shape,X_test.shape,Y_train.shape,Y_test.shape)
# Out:
# (668, 6) (223, 6) (668,) (223,)

# %% [markdown]
# # 10) Use logistic regression by passing your X_train and y_train.#

# %%
from sklearn.linear_model import LogisticRegression
reg = LogisticRegression()
reg.fit(X_train,Y_train)
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='ovr', n_jobs=1,
#           penalty='l2', random_state=None, solver='liblinear', tol=0.0001,
#           verbose=0, warm_start=False)

# %%
y_pred = reg.predict(X_test)

# %% [markdown]
# # 11) Print the accuracy score.#

# %%
score = reg.score(X_test, Y_test)
print(score)
# Out:
# 0.726457399103139
