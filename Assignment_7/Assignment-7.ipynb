# %% [markdown]
# **DESCRIPTION FOR TITANIC DATASET**<BR>
# TOTAL PEOPLE: 887<br>
# AGE: nearly 29<br>
# PCLASS: 3 TYPES<br>
# SEX:2<br>
# NAME OF PASSENGER: ALL UNIQUE<br>
# FARE: nearly 32<br>
# SURVIVED PEOPLE:342 <br>
# Survived people are represented by 1 and who have not survived are represented by 0<br>
# **************************************************************************************
# Age of survived people lies between 0 to 65(80 outlier)
# <br>
# Maximum age of people =80 years <br>
# Number of males are more than females<br>
# Maximum number of people preffered :class3<br>
# Nearly 600 people didnot have parents/siblings/spouse/children in aboard<br>
#
# Almost every female in class1 had survived<br>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
#Q1
data_set = pd.read_csv('titanic.csv')

# %%
data_set.head()
# Out:
#    Survived  Pclass                                               Name  \
# 0         0       3                             Mr. Owen Harris Braund
# 1         1       1  Mrs. John Bradley (Florence Briggs Thayer) Cum...
# 2         1       3                              Miss. Laina Heikkinen
# 3         1       1        Mrs. Jacques Heath (Lily May Peel) Futrelle
# 4         0       3                            Mr. William Henry Allen
#
#       Sex   Age  Siblings/Spouses Aboard  Parents/Children Aboard     Fare
# 0    male  22.0                        1                        0   7.2500
# 1  female  38.0                        1                        0  71.2833
# 2  female  26.0                        0                        0   7.9250
# 3  female  35.0                        1                        0  53.1000
# 4    male  35.0                        0                        0   8.0500

# %%
#Q2.
data_set.describe(include='all')
# Out:
#           Survived      Pclass             Name   Sex         Age  \
# count   887.000000  887.000000              887   887  887.000000
# unique         NaN         NaN              887     2         NaN
# top            NaN         NaN  Mr. Hanna Mamee  male         NaN
# freq           NaN         NaN                1   573         NaN
# mean      0.385569    2.305524              NaN   NaN   29.471443
# std       0.487004    0.836662              NaN   NaN   14.121908
# min       0.000000    1.000000              NaN   NaN    0.420000
# 25%       0.000000    2.000000              NaN   NaN   20.250000
# 50%       0.000000    3.000000              NaN   NaN   28.000000
# 75%       1.000000    3.000000              NaN   NaN   38.000000
# max       1.000000    3.000000              NaN   NaN   80.000000
#
#         Siblings/Spouses Aboard  Parents/Children Aboard       Fare
# count                887.000000               887.000000  887.00000
# ...

# %% [markdown]
# *There are total 887 people in titanic their age is around 29 with deviation of 14.12<br>
# Fare for their voyage is around 32 with deviation of 49.7 <br> *

# %%
#Q4.
data_set.isnull().sum()
# Out:
# Survived                   0
# Pclass                     0
# Name                       0
# Sex                        0
# Age                        0
# Siblings/Spouses Aboard    0
# Parents/Children Aboard    0
# Fare                       0
# dtype: int64

# %% [markdown]
# *No value is undefined in this dataset.*

# %%
data_set['Survived'][data_set['Survived']==1].count()
# Out:
# 342

# %% [markdown]
# *342 people survived.*

# %%
#UNIVARIATE
data_set['Age'].hist()

# %% [markdown]
# *Age ranges from 0 to 75 years.*

# %%
#UNIVARIATE
data_set['Pclass'].hist()

# %% [markdown]
# *Approximately,<br>
# 230 people in class1<br>
# 180 people in class 2<br>
# 480 people in 3 class.*

# %%
#UNIVARIATE
sns.countplot(x='Survived', data=data_set)

# %% [markdown]
# 342 people survived .

# %%
#BIVARIATE
sns.jointplot(x='Survived',y='Age',data=data_set,kind='scatter')
# Out:
# C:\ProgramData\Anaconda31\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# C:\ProgramData\Anaconda31\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %% [markdown]
# *People who had survived are between age(0-65)<br>
# (outlier=75 years)detected.*

# %%
#UNIVARIATE
sns.countplot(x='Sex',data=data_set)

# %% [markdown]
# *There are more males than females<br>
# no of males:560<br>
# no of females:300*

# %%
#UNIVARIATE
sns.countplot(x='Survived', data=data_set, hue='Sex')

# %% [markdown]
# *More number of females survived than males.*

# %%
#UNIVARIATE
pd.crosstab(data_set['Survived'], data_set['Pclass'], margins=True)
# Out:
# Pclass      1    2    3  All
# Survived
# 0          80   97  368  545
# 1         136   87  119  342
# All       216  184  487  887

# %% [markdown]
# *0.24% people survived in class3<br>
# 0.46% people survived in class2<br>
# 0.6%people survived in class1*

# %%
data_set.columns
# Out:
# Index(['Survived', 'Pclass', 'Name', 'Sex', 'Age', 'Siblings/Spouses Aboard',
#        'Parents/Children Aboard', 'Fare'],
#       dtype='object')

# %%
#UNIVARIATE
data_set[['Siblings/Spouses Aboard','Parents/Children Aboard']].hist(figsize=(12,4))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000002BF131FC320>,
# ...
#       dtype=object)

# %% [markdown]
# *680 people who have either 0 or 1 parents/children on aboard <br>
# 90 people who have 2 children/parent on aboard<br>
# and less than 20 people who had more than 3 and less than 6 people on aboard<br>
# <br>
# 600 people with 0/1 siblings/spouse on aboard<br>
# 200 people with 1 on aboard<br>
# less than 50 people with atmost 8 people on aboard*

# %%
#BIVARIATE
sns.jointplot(x='Age', y='Pclass',\
              data=data_set, kind='scatter')
# Out:
# C:\ProgramData\Anaconda31\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# C:\ProgramData\Anaconda31\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %% [markdown]
# *Almost people of every age-group is present in every Pclass.*

# %%
#BIVARIATE
sns.jointplot(x='Pclass', y='Fare',\
              data=data_set, kind='scatter')
# Out:
# C:\ProgramData\Anaconda31\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# C:\ProgramData\Anaconda31\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %% [markdown]
# *class 1 had maximum fare of 500 amount(outlier)
# and had maximum range of 0-270 <br>
# class 2 and 3 had <=100 amount of money*

# %%
#BIVARIATE
sns.lmplot('Pclass', 'Fare', data=data_set)

# %% [markdown]
# *More outliers in case of class1.*

# %%
#BIVARIATE
sns.pairplot(data_set[num_features])

# %%
#BIVARIATE
sns.boxplot(x='Survived', y='Siblings/Spouses Aboard', data=data_set)

# %% [markdown]
# *There are less number of people who have more than 1 siblings/spouses on aboard and had survived.*

# %%
#BIVARIATE
sns.boxplot(x='Survived',y='Parents/Children Aboard',data=data_set)

# %% [markdown]
# *Who have either 0 or 1 parents/children on aboard have survived.*

# %%
#UNIVARIATE
sns.countplot(x='Parents/Children Aboard', data=data_set)

# %% [markdown]
# *More than 600 people didnot have parents/children aboard.*

# %%
#BIVARIATE
sns.boxplot(x='Survived',y='Pclass',data=data_set)

# %% [markdown]
# *Almost all people survived in class1*

# %%
#MULTIVARIATE
num_features = list(set(data_set.columns))

cor_mat = data_set[num_features].corr()

sns.heatmap(cor_mat)
# if non-numerical columns are not subtracted then also values on both x and y axis have numericalvalues

# %% [markdown]
# *pclass and fare shows negative correlation.*

# %% [markdown]
# **Q6**<br>
# ***Select 3 most interesting graphs from the above analysis and describe why those graphs are chosen.***

# %%
#Q6
sns.jointplot(x='Age',y='Fare',data=data_set,kind='scatter')
# Out:
# C:\ProgramData\Anaconda31\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# C:\ProgramData\Anaconda31\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %% [markdown]
# *People of every age have paid less than 100 amount of money*<br>
# *Very few people paid more than 100*

# %%
#Q6
sns.jointplot(x='Age',y='Fare',data=data_set,kind='hex')
# Out:
# C:\ProgramData\Anaconda31\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# C:\ProgramData\Anaconda31\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %% [markdown]
# *between age group of 20-35 people paid less than 50 amount*

# %%
#Q6
sns.boxplot(x='Survived',y='Parents/Children Aboard',data=data_set)

# %% [markdown]
# *People who didnot have any parents/children on aboard didn't died.*
